# %%
a=[1,2,3,4]
b=[10,20,30,40]
c=list(map(lambda a,b:a+b))
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a=[1,2,3,4]
#       2 b=[10,20,30,40]
# ----> 3 c=list(map(lambda a,b:a+b))
#       4 print(c)
#
# TypeError: map() must have at least two arguments.
